# %%
# ============================================================
#  🧠 TREINO — EfficientNet-B0 | Retinopatia Diabética
#  ✅ CLAHE | AMP | Class Weight | Checkpoint frequente
#  👉 Cole tudo em UMA célula do Colab e rode
# ============================================================
# ⚡ ANTES DE RODAR: Ative a GPU
#    Ambiente de execução → Alterar tipo de execução → GPU (T4)
# ============================================================

# ── 1. Instalar dependências ──────────────────────────────────
import subprocess
subprocess.run(["pip", "install", "-q", "timm", "albumentations",
                "opencv-python", "scikit-learn", "tqdm"])

# ── 2. Montar Drive ───────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')

# ── 3. Imports ────────────────────────────────────────────────
import os, gc, time, warnings
import torch
import timm
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import GradScaler, autocast
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tqdm.auto import tqdm
import torch.optim as optim

import albumentations as A
from albumentations.pytorch import ToTensorV2

warnings.filterwarnings('ignore')

# ── 4. Verificar GPU ──────────────────────────────────────────
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Dispositivo: {device}')
if device == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'Memória: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
else:
    print('⚠️  GPU não detectada! Vá em: Ambiente de execução → Alterar tipo → GPU')

# ── 5. Configurações ──────────────────────────────────────────
BASE_PATH            = '/content/drive/MyDrive/RETINOPATIA'
CHECKPOINT_DIR       = '/content/drive/MyDrive/checkpoints_retina'
CHECKPOINT_PATH      = os.path.join(CHECKPOINT_DIR, 'b0_checkpoint.pth')
FINAL_MODEL_PATH     = '/content/drive/MyDrive/retinopatia_model_final.pth'
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

IMG_SIZE             = 224
BATCH_SIZE           = 32
NUM_WORKERS          = 4
EPOCHS               = 10
LR                   = 1e-4
SAVE_EVERY_N_BATCHES = 200
EARLY_STOP_PATIENCE  = 3
USE_AMP              = True

CLASSES = {
    'No_DR': 0,
    'Mild': 1,
    'Moderate': 2,
    'Severe': 3,
    'Proliferate_DR': 4
}

print(f'\n✅ Config: IMG={IMG_SIZE} | BATCH={BATCH_SIZE} | EPOCHS={EPOCHS} | AMP={USE_AMP}')

# ── 6. Montar DataFrame ───────────────────────────────────────
data = []
for c in CLASSES:
    folder = os.path.join(BASE_PATH, c)
    for img in os.listdir(folder):
        data.append([os.path.join(folder, img), CLASSES[c]])

df = pd.DataFrame(data, columns=['image', 'label'])
print(f'\nTotal de imagens: {len(df)}')
print(df['label'].value_counts().sort_index())

# ── 7. Split treino / validação ───────────────────────────────
train_df, val_df = train_test_split(
    df, test_size=0.2, stratify=df['label'], random_state=42
)
print(f'\nTreino: {len(train_df)} | Validação: {len(val_df)}')

# ── 8. CLAHE ──────────────────────────────────────────────────
def apply_clahe(img):
    """
    Realça contraste vascular no espaço LAB (canal L).
    clipLimit=2.0      → evita amplificar ruído de imagens de smartphone
    tileGridSize=(8,8) → adaptação local para estruturas pequenas (microaneurismas)
    """
    lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    l_clahe = clahe.apply(l)
    lab_clahe = cv2.merge([l_clahe, a, b])
    return cv2.cvtColor(lab_clahe, cv2.COLOR_LAB2RGB)

# ── 9. Transformações ─────────────────────────────────────────
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.Affine(scale=(0.95, 1.05), translate_percent=0.05, rotate=(-180, 180), p=0.6),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.3),
    A.GaussianBlur(blur_limit=(3, 5), p=0.2),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2()
])

# ── 10. Dataset ───────────────────────────────────────────────
class RetinaDataset(Dataset):
    def __init__(self, df, transform=None, use_clahe=True):
        self.df        = df.reset_index(drop=True)
        self.transform = transform
        self.use_clahe = use_clahe

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = cv2.imread(row.image)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        if self.use_clahe:
            img = apply_clahe(img)
        if self.transform:
            img = self.transform(image=img)['image']
        return img, int(row.label)

# ── 11. DataLoaders ───────────────────────────────────────────
train_dataset = RetinaDataset(train_df, train_transform, use_clahe=True)
val_dataset   = RetinaDataset(val_df,   val_transform,   use_clahe=True)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=NUM_WORKERS, pin_memory=(device == 'cuda'),
                          persistent_workers=(NUM_WORKERS > 0))
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=(device == 'cuda'),
                          persistent_workers=(NUM_WORKERS > 0))

print(f'\nBatches treino: {len(train_loader)} | Batches val: {len(val_loader)}')

# ── 12. Modelo ────────────────────────────────────────────────
model = timm.create_model('efficientnet_b0', pretrained=True, num_classes=5)
model = model.to(device)

try:
    model = torch.compile(model)
    print('✅ torch.compile() ativado')
except Exception:
    print('ℹ️  torch.compile() indisponível — ok')

# ── 13. Class Weight ──────────────────────────────────────────
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2, 3, 4]),
    y=train_df['label'].values
)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(device)

print('\n📊 Distribuição do treino e pesos:')
print(f'{"Classe":<20} {"Qtd":>8} {"Peso":>8}')
print('-' * 40)
nomes = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']
contagens = train_df['label'].value_counts().sort_index()
for idx, (nome, peso) in enumerate(zip(nomes, class_weights)):
    print(f'{nome:<20} {contagens.get(idx, 0):>8} {peso:>8.4f}')

# ── 14. Loss / Optimizer / Scheduler / Scaler ────────────────
criterion = torch.nn.CrossEntropyLoss(weight=class_weights_tensor)
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=2
)
scaler = GradScaler(enabled=(USE_AMP and device == 'cuda'))

print('\n✅ Loss, optimizer, scheduler e scaler prontos')

# ── 15. Carregar checkpoint (retomada automática) ─────────────
start_epoch        = 0
start_batch        = 0
best_val_loss      = float('inf')
early_stop_counter = 0
history            = []

if os.path.exists(CHECKPOINT_PATH):
    print('\n📂 Checkpoint encontrado — retomando...')
    ckpt = torch.load(CHECKPOINT_PATH, map_location=device)
    model.load_state_dict(ckpt['model'])
    optimizer.load_state_dict(ckpt['optimizer'])
    scaler.load_state_dict(ckpt['scaler'])
    start_epoch        = ckpt.get('epoch', 0)
    start_batch        = ckpt.get('batch', 0)
    best_val_loss      = ckpt.get('best_val_loss', float('inf'))
    early_stop_counter = ckpt.get('early_stop_counter', 0)
    history            = ckpt.get('history', [])
    if start_batch >= len(train_loader):
        start_epoch += 1
        start_batch  = 0
    print(f'   Epoch {start_epoch+1} | batch {start_batch} | best_val_loss {best_val_loss:.4f}')
else:
    print('\n🆕 Nenhum checkpoint — treinando do zero')

# ── 16. Funções auxiliares ────────────────────────────────────
def save_checkpoint(epoch, batch, tag=''):
    torch.save({
        'epoch':              epoch,
        'batch':              batch,
        'model':              model.state_dict(),
        'optimizer':          optimizer.state_dict(),
        'scaler':             scaler.state_dict(),
        'best_val_loss':      best_val_loss,
        'early_stop_counter': early_stop_counter,
        'history':            history,
    }, CHECKPOINT_PATH)
    if tag:
        print(f'   💾 Checkpoint salvo {tag}')

def validate():
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in tqdm(val_loader, desc='Validação', leave=False):
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)
            with autocast(enabled=(USE_AMP and device == 'cuda')):
                preds = model(images)
                loss  = criterion(preds, labels)
            total_loss += loss.item()
            correct    += (preds.argmax(1) == labels).sum().item()
            total      += labels.size(0)
    return total_loss / len(val_loader), correct / total

# ── 17. Loop de treinamento ───────────────────────────────────
print(f'\n🚀 Treinando epochs {start_epoch+1} → {EPOCHS}')
print('=' * 60)

for epoch in range(start_epoch, EPOCHS):
    model.train()
    total_loss  = 0.0
    epoch_start = time.time()

    pbar = tqdm(enumerate(train_loader), total=len(train_loader),
                desc=f'Epoch {epoch+1}/{EPOCHS}', dynamic_ncols=True)

    for batch_idx, (images, labels) in pbar:

        if epoch == start_epoch and batch_idx < start_batch:
            continue

        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        optimizer.zero_grad()

        with autocast(enabled=(USE_AMP and device == 'cuda')):
            preds = model(images)
            loss  = criterion(preds, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item()
        avg_loss    = total_loss / (batch_idx - start_batch + 1)

        pbar.set_postfix({'loss': f'{avg_loss:.4f}',
                          'lr':   f'{optimizer.param_groups[0]["lr"]:.2e}'})

        if (batch_idx + 1) % SAVE_EVERY_N_BATCHES == 0:
            save_checkpoint(epoch, batch_idx + 1,
                            tag=f'(epoch {epoch+1}, batch {batch_idx+1})')

    start_batch = 0

    val_loss, val_acc = validate()
    elapsed = time.time() - epoch_start

    print(f'\nEpoch {epoch+1}/{EPOCHS} | Train Loss: {avg_loss:.4f} | '
          f'Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f} | '
          f'Tempo: {elapsed/60:.1f} min')

    history.append({'epoch': epoch+1, 'train_loss': avg_loss,
                    'val_loss': val_loss, 'val_acc': val_acc})

    scheduler.step(val_loss)

    if val_loss < best_val_loss:
        best_val_loss      = val_loss
        early_stop_counter = 0
        torch.save(model.state_dict(), FINAL_MODEL_PATH)
        print(f'   ⭐ Melhor modelo salvo! Val Loss: {val_loss:.4f}')
    else:
        early_stop_counter += 1
        print(f'   ⚠️  Sem melhoria ({early_stop_counter}/{EARLY_STOP_PATIENCE})')
        if early_stop_counter >= EARLY_STOP_PATIENCE:
            print('🛑 Early stopping!')
            save_checkpoint(epoch, len(train_loader), tag='(early stop)')
            break

    save_checkpoint(epoch + 1, 0, tag=f'(fim epoch {epoch+1})')
    print('=' * 60)

print('\n🏁 Treino finalizado!')

# ── 18. Gráficos ─────────────────────────────────────────────
if history:
    epochs_done  = [h['epoch']      for h in history]
    train_losses = [h['train_loss'] for h in history]
    val_losses   = [h['val_loss']   for h in history]
    val_accs     = [h['val_acc']    for h in history]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    ax1.plot(epochs_done, train_losses, label='Train Loss', marker='o')
    ax1.plot(epochs_done, val_losses,   label='Val Loss',   marker='o')
    ax1.set_title('Loss por Epoch'); ax1.legend(); ax1.grid(True)
    ax2.plot(epochs_done, val_accs, label='Val Accuracy', color='green', marker='o')
    ax2.set_title('Acurácia de Validação'); ax2.legend(); ax2.grid(True)
    plt.tight_layout()
    plt.show()
    print(pd.DataFrame(history).to_string(index=False))

# ── 19. Verificar arquivos no Drive ──────────────────────────
print('\n📁 Arquivos salvos:')
for path, label in [(CHECKPOINT_PATH, 'Checkpoint'), (FINAL_MODEL_PATH, 'Modelo final')]:
    if os.path.exists(path):
        print(f'  ✅ {label}: {path} ({os.path.getsize(path)/1e6:.1f} MB)')
    else:
        print(f'  ❌ {label} não encontrado: {path}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dispositivo: cuda
# GPU: Tesla T4
# Memória: 15.6 GB
#
# ✅ Config: IMG=224 | BATCH=32 | EPOCHS=10 | AMP=True
#
# Total de imagens: 35135
# label
# 0    25817
# 1     2444
# 2     5292
# 3      873
# 4      709
# Name: count, dtype: int64
#
# Treino: 28108 | Validação: 7027
#
# Batches treino: 879 | Batches val: 220
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ✅ torch.compile() ativado
#
# 📊 Distribuição do treino e pesos:
# Classe                    Qtd     Peso
# ----------------------------------------
# No_DR                   20654   0.2722
# Mild                     1955   2.8755
# Moderate                 4234   1.3277
# Severe                    698   8.0539
# Proliferate_DR            567   9.9146
#
# ✅ Loss, optimizer, scheduler e scaler prontos
#
# 🆕 Nenhum checkpoint — treinando do zero
#
# 🚀 Treinando epochs 1 → 10
# ============================================================
# Epoch 1/10:   0%|          | 0/879 [00:00<?, ?it/s]
# W0310 12:53:32.426000 7795 torch/_inductor/utils.py:1679] [0/0] Not enough SMs to use max_autotune_gemm mode
#    💾 Checkpoint salvo (epoch 1, batch 200)
#    💾 Checkpoint salvo (epoch 1, batch 400)
#    💾 Checkpoint salvo (epoch 1, batch 600)
#    💾 Checkpoint salvo (epoch 1, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 1/10 | Train Loss: 1.9645 | Val Loss: 1.4334 | Val Acc: 0.4000 | Tempo: 62.8 min
#    ⭐ Melhor modelo salvo! Val Loss: 1.4334
#    💾 Checkpoint salvo (fim epoch 1)
# ============================================================
# Epoch 2/10:   0%|          | 0/879 [00:00<?, ?it/s]
#    💾 Checkpoint salvo (epoch 2, batch 200)
#    💾 Checkpoint salvo (epoch 2, batch 400)
#    💾 Checkpoint salvo (epoch 2, batch 600)
#    💾 Checkpoint salvo (epoch 2, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 2/10 | Train Loss: 1.3416 | Val Loss: 1.2882 | Val Acc: 0.3795 | Tempo: 6.2 min
#    ⭐ Melhor modelo salvo! Val Loss: 1.2882
#    💾 Checkpoint salvo (fim epoch 2)
# ============================================================
# Epoch 3/10:   0%|          | 0/879 [00:00<?, ?it/s]
#    💾 Checkpoint salvo (epoch 3, batch 200)
#    💾 Checkpoint salvo (epoch 3, batch 400)
#    💾 Checkpoint salvo (epoch 3, batch 600)
#    💾 Checkpoint salvo (epoch 3, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 3/10 | Train Loss: 1.2172 | Val Loss: 1.1932 | Val Acc: 0.4588 | Tempo: 5.9 min
#    ⭐ Melhor modelo salvo! Val Loss: 1.1932
#    💾 Checkpoint salvo (fim epoch 3)
# ============================================================
# Epoch 4/10:   0%|          | 0/879 [00:00<?, ?it/s]
#    💾 Checkpoint salvo (epoch 4, batch 200)
#    💾 Checkpoint salvo (epoch 4, batch 400)
#    💾 Checkpoint salvo (epoch 4, batch 600)
#    💾 Checkpoint salvo (epoch 4, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 4/10 | Train Loss: 1.1692 | Val Loss: 1.1681 | Val Acc: 0.5526 | Tempo: 6.1 min
#    ⭐ Melhor modelo salvo! Val Loss: 1.1681
#    💾 Checkpoint salvo (fim epoch 4)
# ============================================================
# Epoch 5/10:   0%|          | 0/879 [00:00<?, ?it/s]
#    💾 Checkpoint salvo (epoch 5, batch 200)
#    💾 Checkpoint salvo (epoch 5, batch 400)
#    💾 Checkpoint salvo (epoch 5, batch 600)
#    💾 Checkpoint salvo (epoch 5, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 5/10 | Train Loss: 1.1320 | Val Loss: 1.1592 | Val Acc: 0.4063 | Tempo: 6.1 min
#    ⭐ Melhor modelo salvo! Val Loss: 1.1592
#    💾 Checkpoint salvo (fim epoch 5)
# ============================================================
# Epoch 6/10:   0%|          | 0/879 [00:00<?, ?it/s]
#    💾 Checkpoint salvo (epoch 6, batch 200)
#    💾 Checkpoint salvo (epoch 6, batch 400)
#    💾 Checkpoint salvo (epoch 6, batch 600)
#    💾 Checkpoint salvo (epoch 6, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 6/10 | Train Loss: 1.0943 | Val Loss: 1.1726 | Val Acc: 0.5633 | Tempo: 6.0 min
#    ⚠️  Sem melhoria (1/3)
#    💾 Checkpoint salvo (fim epoch 6)
# ============================================================
# Epoch 7/10:   0%|          | 0/879 [00:00<?, ?it/s]
#    💾 Checkpoint salvo (epoch 7, batch 200)
#    💾 Checkpoint salvo (epoch 7, batch 400)
#    💾 Checkpoint salvo (epoch 7, batch 600)
#    💾 Checkpoint salvo (epoch 7, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 7/10 | Train Loss: 1.0615 | Val Loss: 1.1605 | Val Acc: 0.3257 | Tempo: 6.0 min
#    ⚠️  Sem melhoria (2/3)
#    💾 Checkpoint salvo (fim epoch 7)
# ============================================================
# Epoch 8/10:   0%|          | 0/879 [00:00<?, ?it/s]
#    💾 Checkpoint salvo (epoch 8, batch 200)
#    💾 Checkpoint salvo (epoch 8, batch 400)
#    💾 Checkpoint salvo (epoch 8, batch 600)
#    💾 Checkpoint salvo (epoch 8, batch 800)
# Validação:   0%|          | 0/220 [00:00<?, ?it/s]
# Epoch 8/10 | Train Loss: 1.0378 | Val Loss: 1.1696 | Val Acc: 0.5342 | Tempo: 6.1 min
#    ⚠️  Sem melhoria (3/3)
# 🛑 Early stopping!
#    💾 Checkpoint salvo (early stop)
#
# 🏁 Treino finalizado!
#  epoch  train_loss  val_loss  val_acc
#      1    1.964485  1.433428 0.400028
#      2    1.341594  1.288209 0.379536
#      3    1.217226  1.193188 0.458802
#      4    1.169221  1.168082 0.552583
#      5    1.132007  1.159184 0.406290
#      6    1.094328  1.172568 0.563256
#      7    1.061472  1.160550 0.325744
#      8    1.037810  1.169627 0.534225
#
# 📁 Arquivos salvos:
#   ✅ Checkpoint: /content/drive/MyDrive/checkpoints_retina/b0_checkpoint.pth (48.7 MB)
#   ✅ Modelo final: /content/drive/MyDrive/retinopatia_model_final.pth (16.4 MB)
